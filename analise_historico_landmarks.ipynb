# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('pose_analysis_20260402_225212.csv')
df
# Out:
#        frame  processed_frame  timestamp_s  model  processing_time_ms  \
# 0          0                0     0.000000  heavy          151.081324
# 1          0                0     0.000000  heavy          151.081324
# 2          0                0     0.000000  heavy          151.081324
# 3          0                0     0.000000  heavy          151.081324
# 4          0                0     0.000000  heavy          151.081324
# ...      ...              ...          ...    ...                 ...
# 10423   1101             1101    36.867503  heavy          149.842501
# 10424   1101             1101    36.867503  heavy          149.842501
# 10425   1101             1101    36.867503  heavy          149.842501
# 10426   1101             1101    36.867503  heavy          149.842501
# 10427   1101             1101    36.867503  heavy          149.842501
#
#        landmark_idx      landmark_name         x         y         z  \
# ...
